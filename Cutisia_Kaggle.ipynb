# %% [markdown]
# # 🏥 Cutisia Elite AI - Kaggle Edition (Mobile Monitoring)
#
# Ce notebook permet d'entraîner le modèle **EfficientNetV2-L** avec monitoring en temps réel sur votre smartphone via **Weights & Biases**.
#
# **Note** : Assurez-vous d'avoir ajouté le dataset `scribeassistant/cutisiav2` à votre session Kaggle.

# %% [markdown]
# ### 1️⃣ Préparation de l'environnement
# On installe WandB et on récupère le code de la branche `kaggle-version`.

# %%
# !pip install -q wandb
# !rm -rf skin-disease-detector
# !git clone https://github.com/franck504/skin-disease-detector.git
# !cd skin-disease-detector && git checkout kaggle-version

# %% [markdown]
# ### 1.5️⃣ Connexion à Weights & Biases
# Cliquez sur le lien qui apparaîtra ci-dessous pour récupérer votre **API KEY** et collez-la dans le champ.

# %%
import wandb
wandb.login()

# %% [markdown]
# ### 2️⃣ Audit du Dataset

# %%
# !python3 skin-disease-detector/audit_dataset.py

# %% [markdown]
# ### 3️⃣ Lancement de l'Entraînement Elite (avec WandB)
# Suivez les courbes en direct sur votre smartphone via l'application WandB !

# %%
# !python3 skin-disease-detector/train_dual_models.py
